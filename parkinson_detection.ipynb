# %%
# importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset
data = pd.read_csv('parkinson_desease.csv')
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
# get dataset info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
# check number of rows and columns
data.shape
# Out:
# (195, 24)

# %%
# checking the number of values in the target column
data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# check if there is any null in the dataset
data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
# creating a visualization of the data
data.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'MDVP:Fo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Fhi(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Flo(Hz)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(%)'}>,
#         <Axes: title={'center': 'MDVP:Jitter(Abs)'}>],
#        [<Axes: title={'center': 'MDVP:RAP'}>,
#         <Axes: title={'center': 'MDVP:PPQ'}>,
#         <Axes: title={'center': 'Jitter:DDP'}>,
#         <Axes: title={'center': 'MDVP:Shimmer'}>,
#         <Axes: title={'center': 'MDVP:Shimmer(dB)'}>],
#        [<Axes: title={'center': 'Shimmer:APQ3'}>,
#         <Axes: title={'center': 'Shimmer:APQ5'}>,
#         <Axes: title={'center': 'MDVP:APQ'}>,
#         <Axes: title={'center': 'Shimmer:DDA'}>,
#         <Axes: title={'center': 'NHR'}>],
#        [<Axes: title={'center': 'HNR'}>,
#         <Axes: title={'center': 'status'}>,
#         <Axes: title={'center': 'RPDE'}>,
#         <Axes: title={'center': 'DFA'}>,
#         <Axes: title={'center': 'spread1'}>],
# ...

# %%
# checking the data stats
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
# dropping useless column
data = data.drop(['name'], axis=1)

# %%
# checking the mean value for each target output
data.groupby('status').mean()
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
# splitting the data in feature and target datasets
X = data.drop(['status'], axis=1)
y = data['status']

# %%
# splitting and training datasets
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
# import module
from sklearn.svm import SVC

# %%
# training and predicting the output
model = SVC()
model.fit(X_train, y_train)
pred = model.predict(X_train)

# %%
# importing metrics
from sklearn.metrics import classification_report

# %%
# applying metrics to train dataset
classification = classification_report(y_train, pred)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.27      0.42        41
#            1       0.79      1.00      0.88       115
#
#     accuracy                           0.81       156
#    macro avg       0.90      0.63      0.65       156
# weighted avg       0.85      0.81      0.76       156

# %%
# applying metrics to test dataset
pred_test = model.predict(X_test)
acc_test = classification_report(y_test, pred_test)
print(acc_test)
# the results are not good
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.82      1.00      0.90        32
#
#     accuracy                           0.82        39
#    macro avg       0.41      0.50      0.45        39
# weighted avg       0.67      0.82      0.74        39
# c:\Users\adams\Desktop\machine_learning\portfolio_machine_learning\parkison_desease_svm\env\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# c:\Users\adams\Desktop\machine_learning\portfolio_machine_learning\parkison_desease_svm\env\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Implementing Standard Scaler

# %%
# as the results for test dataset are not good we scale the dataset to try to improve the prediction
# importing Standard Scale module
from sklearn.preprocessing import  StandardScaler

# %%
# scaling, training and prediction test
scale = StandardScaler()

scale.fit(X_train)

X_scaled_train = scale.transform(X_train)

X_scaled_test = scale.transform(X_test)

# %%
# printing the scale dataset
print(X_scaled_train)
# Out:
# [[-0.80172872 -0.70830513 -0.10603303 ...  0.89854281 -0.48294197
#    1.64980971]
#  [-1.04374224 -0.74950432 -0.29919921 ...  1.17531845  0.65177741
#    0.26864313]
#  [-0.3790498   0.13122544 -0.82039362 ... -0.7771489  -0.73102398
#    0.28542547]
#  ...
#  [-0.13744368 -0.31583967  0.56292775 ... -1.65126173 -0.08248373
#   -0.17764131]
#  [-0.14053505 -0.42034011  0.39263744 ...  0.19569946  1.19665768
#   -0.11105606]
#  [-0.35427092  4.57536567 -1.22354854 ...  0.55494177  0.80279984
#    2.57800238]]

# %%
# fitting and predicting train dataset
model = SVC()
model.fit(X_scaled_train, y_train)
pred_scaled = model.predict(X_scaled_train)
acc_test = classification_report(y_train, pred_scaled)
print(acc_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74        41
#            1       0.87      1.00      0.93       115
#
#     accuracy                           0.89       156
#    macro avg       0.94      0.79      0.83       156
# weighted avg       0.91      0.89      0.88       156

# %%
# fitting and predicting test dataset
pred_scaled_test = model.predict(X_scaled_test)
acc_scale_test = classification_report(y_test, pred_scaled_test)
print(acc_scale_test)
# the standard scaler helped to improve dramatically the resultos of predictions
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.89      1.00      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.94      0.71      0.77        39
# weighted avg       0.91      0.90      0.88        39

# %% [markdown]
# ## Building a prediction system

# %%
# choosing a random data to test the model
input_data = (120.267,137.244,114.82,0.00333,0.00003,0.00155,0.00202,0.00466,0.01608,0.14,0.00779,0.00937,0.01351,0.02337,0.00607,24.886,0.59604,0.764112,-5.634322,0.257682,1.854785,0.211756)

input_data = np.asarray(input_data)

input_data = input_data.reshape(1,-1)

#standard scaler
std_data = scale.transform(input_data)

pred_input_data = model.predict(std_data)

if pred_input_data == 0:
    print('Do not have Parkinson')
else:
    print('Have Parkinson')
# the model predicted correctly the output
# Out:
# Have Parkinson
# c:\Users\adams\Desktop\machine_learning\portfolio_machine_learning\parkison_desease_svm\env\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
